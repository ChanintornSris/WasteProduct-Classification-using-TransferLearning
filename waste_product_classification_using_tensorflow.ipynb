# %% [markdown]
# # <a id='toc1_'></a>[**Classify Waste Products Using Transfer Learning**](#toc0_)

# %% [markdown]
# **Contents**<a id='toc0_'></a>
# - [**Classify Waste Products Using Transfer Learning**](#toc1_)
#   - [Introduction](#toc1_1_)
#     - [Project Overview](#toc1_1_1_)
#     - [Aim of the Project](#toc1_1_2_)
#   - [Objectives](#toc1_2_)
#     - [Tasks List](#toc1_2_1_)
#     - [Sample Task: Sample screenshot showing code and output](#toc1_2_2_)
#   - [Setup](#toc1_3_)
#     - [Installing Required Libraries](#toc1_3_1_)
#     - [Importing Required Libraries](#toc1_3_2_)
#   - [Task 1: Observe the version of tensorflow](#toc1_4_)
#     - [Background](#toc1_5_)
#     - [Create a model for distinguishing recyclable and organic waste images](#toc1_6_)
#     - [Dataset](#toc1_6_1_)
#     - [Data Source](#toc1_6_2_)
#     - [Define configuration options](#toc1_6_3_)
#     - [Loading Images using ImageGeneratorClass](#toc1_6_4_)
#       - [ImageDataGenerators](#toc1_6_4_1_)
#   - [Task 2: Create a `test_generator` using the `test_datagen` object](#toc1_7_)
#   - [Task 3: Observe the length of the `train_generator`](#toc1_8_)
#     - [Pre-trained Models](#toc1_8_1_)
#       - [VGG-16](#toc1_8_1_1_)
#   - [Task 4: Observe the summary of the model](#toc1_9_)
#   - [Task 5: Compile the model](#toc1_10_)
#     - [Fit and train the model](#toc1_11_)
#     - [Plot loss curves for training and validation sets (extract_feat_model)](#toc1_11_1_)
#   - [Task 6: Plot accuracy curves for training and validation sets (extract_feat_model)](#toc1_11_2_)
#     - [Fine-Tuning model](#toc1_12_)
#   - [Task 7: Plot loss curves for training and validation sets (fine tune model)](#toc1_12_1_)
#   - [Task 8: Plot accuracy curves for training and validation sets  (fine tune model)](#toc1_12_2_)
#     - [Evaluate both models on Test data (Unseen data)](#toc1_13_)
#     - [Summary Model Performance](#toc1_12_3_)
#   - [Task 9: Plot a test image using Extract Features Model (index_to_plot = 6)](#toc1_13_1_)
#   - [Task 10: Plot a test image using Fine-Tuned Model (index_to_plot = 6)](#toc1_13_2_)
#   -  [Conclusion](#toc0_)
#
#
# ### <a id='toc1_1_1_'></a>[Project Overview](#toc0_)
#
# EcoClean currently lacks an efficient and scalable method to automate the waste sorting process. The manual sorting of waste is not only labor-intensive but also prone to errors, leading to contamination of recyclable materials. The goal of this project is to leverage machine learning and computer vision to automate the classification of waste products, improving efficiency and reducing contamination rates. The project will use transfer learning with a pre-trained VGG16 model to classify images.
#
# ### <a id='toc1_1_2_'></a>[Aim of the Project](#toc0_)
#
# The aim of the project is to develop an automated waste classification model that can accurately differentiate between recyclable and organic waste based on images. By the end of this project, we will have trained, fine-tuned, and evaluated a model using transfer learning, which can then be applied to real-world waste management processes.
#
# **Final Output**: A trained model that classifies waste images into recyclable and organic categories.

# %% [markdown]
# ## <a id='toc1_2_'></a>[Objectives](#toc0_)
#
# - Apply transfer learning using the VGG16 model for image classification.
# - Prepare and preprocess image data for a machine learning task.
# - Fine-tune a pre-trained model to improve classification accuracy.
# - Evaluate the model’s performance using appropriate metrics.
# - Visualize model predictions on test data.
#
# By completing these objectives, we will be able to apply the techniques in real-world scenarios, such as automating waste sorting for municipal or industrial use.
#
# ### <a id='toc1_2_1_'></a>[Tasks List](#toc0_)
# To achieve the above objectives, we will complete the following tasks:
#
# - Task 1: Observe the version of tensorflow
# - Task 2: Create a `test_generator` using the `test_datagen` object
# - Task 3: Observe the length of the `train_generator`
# - Task 4: Observe the summary of the model
# - Task 5: Compile the model
# - Task 6: Plot accuracy curves for training and validation sets (extract_feat_model)
# - Task 7: Plot loss curves for training and validation sets (fine tune model)
# - Task 8: Plot accuracy curves for training and validation sets  (fine tune model)
# - Task 9: Plot a test image using Extract Features Model (index_to_plot = 6)
# - Task 10: Plot a test image using Fine-Tuned Model (index_to_plot = 6)
#
# <br>
#
# ---

# %% [markdown]
# ## <a id='toc1_3_'></a>[Setup](#toc0_)
#
# For this lab, we will be using the following libraries:
#
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.
# *   [`tensorflow`](https://www.tensorflow.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and neural network related functions.
#
#
# ### <a id='toc1_3_1_'></a>[Installing Required Libraries](#toc0_)

# %%
# !pip install tensorflow==2.17.0 | tail -n 1
# !pip install numpy==1.26.4 | tail -n 1
# !pip install scikit-learn==1.5.1  | tail -n 1
# !pip install matplotlib==3.9.2  | tail -n 1
# Out:
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google-pasta-0.2.0 grpcio-1.78.0 h5py-3.15.1 keras-3.13.2 libclang-18.1.1 markdown-3.10.2 markdown-it-py-4.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.1.0 numpy-1.26.4 opt-einsum-3.4.0 optree-0.19.0 protobuf-4.25.8 rich-14.3.3 tensorboard-2.17.1 tensorboard-data-server-0.7.2 tensorflow-2.17.0 termcolor-3.3.0 werkzeug-3.1.6 wrapt-2.1.2
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.12/site-packages (1.26.4)
# Successfully installed joblib-1.5.3 scikit-learn-1.5.1 scipy-1.17.1 threadpoolctl-3.6.0
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.9.2 pillow-12.1.1 pyparsing-3.3.2

# %% [markdown]
# ### <a id='toc1_3_2_'></a>[Importing Required Libraries](#toc0_)

# %%
import numpy as np
import os
# import random, shutil
import glob


from matplotlib import pyplot as plt
from matplotlib import pyplot
from matplotlib.image import imread
from matplotlib.ticker import MaxNLocator

# from os import makedirs,listdir
# from shutil import copyfile
# from random import seed
# from random import random

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# from tensorflow.keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D, Input
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications import InceptionV3
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <a id='toc1_4_'></a>[**Task 1: Observe the version of tensorflow**](#toc0_)

# %%
print('tensorflow version : ',tf.__version__)
# Out:
# tensorflow version :  2.17.0

# %% [markdown]
# ## <a id='toc1_5_'></a>[Background](#toc0_)
#
#
# **Transfer learning** uses the concept of keeping the early layers of a pre-trained network, and re-training the later layers on a specific dataset. we can leverage some state of that network on a related task.
#
# A typical transfer learning workflow in Keras looks something like this:
#
# 1.  Initialize base model, and load pre-trained weights (e.g. ImageNet)
# 2.  "Freeze" layers in the base model by setting `training = False`
# 3.  Define a new model that goes on top of the output of the base model's layers.
# 4.  Train resulting model on wer data set.
#
# ## <a id='toc1_6_'></a>[Create a model for distinguishing recyclable and organic waste images](#toc0_)
#
# ### <a id='toc1_6_1_'></a>[Dataset](#toc0_)
#
# we will be using the [Waste Classification Dataset](https://www.kaggle.com/datasets/techsash/waste-classification-data?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera35714171-2022-01-01).
#
# wer goal is to train an algorithm on these images and to predict the labels for images in wer test set (1 = recyclable, 0 = organic).
#
# ### <a id='toc1_6_2_'></a>[Data Source](#toc0_)
#
# We have prepared image data located within the `o-vs-r-split` folder.

# %% [markdown]
# ### <a id='toc1_6_3_'></a>[Define configuration options](#toc0_)
#
# It's time to define some model configuration options.
#
# *   **batch size** is set to 32.
# *   The **number of classes** is 2.
# *   we will use 20% of the data for **validation** purposes.
# *   we have two **labels** in wer dataset: organic (O), recyclable (R).

# %%
img_rows, img_cols = 150, 150
batch_size = 32
n_epochs = 20
n_classes = 2
val_split = 0.2
verbosity = 1
path = 'o-vs-r-split/train/'
path_test = 'o-vs-r-split/test/'
input_shape = (img_rows, img_cols, 3)
labels = ['O', 'R']
seed = 42

# %% [markdown]
# ### <a id='toc1_6_4_'></a>[Loading Images using ImageGeneratorClass](#toc0_)
#
# Transfer learning works best when models are trained on smaller datasets.
#
# The folder structure looks as follows:
#
# ```python
# o-vs-r-split/
# └── train
#     ├── O
#     └── R
# └── test
#     ├── O
#     └── R
# ```
#
#
# #### <a id='toc1_6_4_1_'></a>[ImageDataGenerators](#toc0_)
#
#
# Now we will create ImageDataGenerators used for training, validation and testing.
#
# Image data generators create batches of tensor image data with real-time data augmentation. The generators loop over the data in batches and are useful in feeding data to the training process.

# %% [markdown]
# <br>
#
# ##### Create ImageDataGenerators for training and validation and testing

# %%
train_datagen = ImageDataGenerator(
    validation_split = val_split,
    rescale=1.0/255.0,
	width_shift_range=0.1, 
    height_shift_range=0.1, 
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(
    validation_split = val_split,
    rescale=1.0/255.0,
)

test_datagen = ImageDataGenerator(
    rescale=1.0/255.0
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = path,
    seed = seed,
    batch_size = batch_size, 
    class_mode='binary',
    shuffle = True,
    target_size=(img_rows, img_cols),
    subset = 'training'
)
# Out:
# Found 800 images belonging to 2 classes.

# %%
val_generator = val_datagen.flow_from_directory(
    directory = path,
    seed = seed,
    batch_size = batch_size, 
    class_mode='binary',
    shuffle = True,
    target_size=(img_rows, img_cols),
    subset = 'validation'
)
# Out:
# Found 200 images belonging to 2 classes.

# %% [markdown]
# ## <a id='toc1_7_'></a>[**Task 2: Create a `test_generator` using the `test_datagen` object**](#toc0_)
#
# *   **directory** should be set to `path_test`.
# *   **class_mode** should be set to `'binary'`.
# *   **seed** should be set to `seed`.
# *   **batch_size** should be set to `batch_size`.
# *   **shuffle** should be set to `False`.
# *   **target_size** should be set to `(img_rows, img_cols)`.

# %%
test_generator = test_datagen.flow_from_directory(
    directory=path_test,
    class_mode='binary',
    seed=seed,
    batch_size=batch_size,
    shuffle=False,
    target_size=(img_rows, img_cols)
)
# Out:
# Found 200 images belonging to 2 classes.

# %% [markdown]
# ## <a id='toc1_8_'></a>[**Task 3: Observe the length of the `train_generator`**](#toc0_)

# %%
print('Generator Leangth :',len(train_generator))
# Out:
# Generator Leangth : 25

# %%
from pathlib import Path

IMG_DIM = (100, 100)

train_files = glob.glob('./o-vs-r-split/train/O/*')
train_files = train_files[:20]
train_imgs = [tf.keras.preprocessing.image.img_to_array(tf.keras.preprocessing.image.load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [Path(fn).parent.name for fn in train_files]

img_id = 0
O_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
O = [next(O_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in O])
l = [ax[i].imshow(O[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['O', 'O', 'O', 'O', 'O']

# %% [markdown]
# ### <a id='toc1_8_1_'></a>[Pre-trained Models](#toc0_)
#
# Pre-trained models are saved networks that have previously been trained on some large datasets. They are typically used for large-scale image-classification task. They can be used as they are or could be customized to a given task using transfer learning. These pre-trained models form the basis of transfer learning.
#
# #### <a id='toc1_8_1_1_'></a>[VGG-16](#toc0_)
#
# Let us load the VGG16 model.

# %%
from tensorflow.keras.applications import vgg16

input_shape = (150, 150, 3)
vgg = vgg16.VGG16(include_top=False,
                        weights='imagenet',
                        input_shape=input_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# We flatten the output of a vgg model and assign it to the model `output`, we then use a Model object `basemodel` to group the layers into an object for training and inference .
# With the following inputs and outputs
#
# inputs: `vgg.input`
#
# outputs: `tf.keras.layers.Flatten()(output)`

# %%
output = vgg.layers[-1].output
output = tf.keras.layers.Flatten()(output)
basemodel = Model(vgg.input, output)

# %% [markdown]
# Next, freeze the basemodel.

# %%
for layer in basemodel.layers:
    layer.trainable = False

print(f"{'Layer Name'} | {'Trainable'}")
print("-" * 38)
for layer in basemodel.layers:
    print(f"{layer.name:<25} | {layer.trainable}")
# Out:
# Layer Name | Trainable
# --------------------------------------
# input_layer               | False
# block1_conv1              | False
# block1_conv2              | False
# block1_pool               | False
# block2_conv1              | False
# block2_conv2              | False
# block2_pool               | False
# block3_conv1              | False
# block3_conv2              | False
# block3_conv3              | False
# block3_pool               | False
# block4_conv1              | False
# block4_conv2              | False
# block4_conv3              | False
# block4_pool               | False
# block5_conv1              | False
# block5_conv2              | False
# block5_conv3              | False
# block5_pool               | False
# flatten                   | False

# %% [markdown]
# Create a new model on top. we add a Dropout layer for regularization, only these layers will change as for the lower layers we set `training=False` when calling the base model.

# %%
input_shape = basemodel.output_shape[1]

model = Sequential()
model.add(basemodel)
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## <a id='toc1_9_'></a>[**Task 4: Observe the summary of the model**](#toc0_)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 8192)           │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     4,194,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,172,673 (73.14 MB)
#  Trainable params: 4,457,985 (17.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## <a id='toc1_10_'></a>[**Task 5: Compile the model**](#toc0_)
#
# we will compile the model using the following parameters:
#
# *   **loss**: `'binary_crossentropy'`.
# *   **optimizer**: `tf.keras.optimizers.Adam(learning_rate=1e-5)`.
# *   **metrics**: `['accuracy']`.

# %%
for layer in basemodel.layers: 
    layer.trainable = False

# Task 5: Compile the model
model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    metrics=['accuracy']
)

# %% [markdown]
# Use early stopping to avoid over-training the model.

# %%
from tensorflow.keras.callbacks import LearningRateScheduler


checkpoint_path='O_R_tlearn_vgg16.keras'

# define step decay function
class LossHistory_(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.lr = []
        
    def on_epoch_end(self, epoch, logs={}):
        self.losses.append(logs.get('loss'))
        self.lr.append(exp_decay(epoch))
        print('lr:', exp_decay(len(self.losses)))

def exp_decay(epoch):
    initial_lrate = 1e-4
    k = 0.1
    lrate = initial_lrate * np.exp(-k*epoch)
    return lrate

# learning schedule callback
loss_history_ = LossHistory_()
lrate_ = LearningRateScheduler(exp_decay)

keras_callbacks = [
      EarlyStopping(monitor = 'val_loss', 
                    patience = 4, 
                    mode = 'min', 
                    min_delta=0.01),
      ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')
]

callbacks_list_ = [loss_history_, lrate_] + keras_callbacks

# %% [markdown]
# ## <a id='toc1_11_'></a>[Fit and train the model](#toc0_)

# %%
extract_feat_model = model.fit(train_generator, 
                               steps_per_epoch=5, 
                               epochs=n_epochs,
                               callbacks = callbacks_list_,   
                               validation_data=val_generator, 
                               validation_steps=val_generator.samples // batch_size, 
                               verbose=1)
# Out:
# Epoch 1/20
# lr: 9.048374180359596e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5717 - loss: 0.7381
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 69s 15s/step - accuracy: 0.5562 - loss: 0.7163 - val_accuracy: 0.7969 - val_loss: 0.5881 - learning_rate: 1.0000e-04
# Epoch 2/20
# lr: 8.187307530779819e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6347 - loss: 0.6328
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 60s 14s/step - accuracy: 0.6500 - loss: 0.6412 - val_accuracy: 0.8229 - val_loss: 0.5144 - learning_rate: 9.0484e-05
# Epoch 3/20
# lr: 7.408182206817179e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6754 - loss: 0.6293
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 55s 12s/step - accuracy: 0.6687 - loss: 0.6050 - val_accuracy: 0.6927 - val_loss: 0.5524 - learning_rate: 8.1873e-05
# Epoch 4/20
# lr: 6.703200460356393e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7280 - loss: 0.5648
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.7312 - loss: 0.5525 - val_accuracy: 0.8542 - val_loss: 0.4419 - learning_rate: 7.4082e-05
# Epoch 5/20
# lr: 6.065306597126335e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8110 - loss: 0.4509
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 58s 13s/step - accuracy: 0.8000 - loss: 0.4541 - val_accuracy: 0.8177 - val_loss: 0.4365 - learning_rate: 6.7032e-05
# Epoch 6/20
# lr: 5.488116360940264e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7679 - loss: 0.5036
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 13s/step - accuracy: 0.7875 - loss: 0.4692 - val_accuracy: 0.8542 - val_loss: 0.4040 - learning_rate: 6.0653e-05
# Epoch 7/20
# lr: 4.9658530379140954e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7090 - loss: 0.5222
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 55s 12s/step - accuracy: 0.7688 - loss: 0.4654 - val_accuracy: 0.8281 - val_loss: 0.4084 - learning_rate: 5.4881e-05
# Epoch 8/20
# lr: 4.493289641172216e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7644 - loss: 0.4818
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 13s/step - accuracy: 0.7750 - loss: 0.4872 - val_accuracy: 0.8594 - val_loss: 0.3780 - learning_rate: 4.9659e-05
# Epoch 9/20
# lr: 4.0656965974059915e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8318 - loss: 0.4072
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 13s/step - accuracy: 0.8438 - loss: 0.3974 - val_accuracy: 0.8438 - val_loss: 0.3683 - learning_rate: 4.4933e-05
# Epoch 10/20
# lr: 3.678794411714424e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7742 - loss: 0.4300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 13s/step - accuracy: 0.8188 - loss: 0.3894 - val_accuracy: 0.8594 - val_loss: 0.3578 - learning_rate: 4.0657e-05
# Epoch 11/20
# lr: 3.3287108369807955e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8448 - loss: 0.3771
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 12s/step - accuracy: 0.8125 - loss: 0.4127 - val_accuracy: 0.8438 - val_loss: 0.3594 - learning_rate: 3.6788e-05
# Epoch 12/20
# lr: 3.0119421191220204e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8638 - loss: 0.3151
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 54s 12s/step - accuracy: 0.8500 - loss: 0.3355 - val_accuracy: 0.8542 - val_loss: 0.3581 - learning_rate: 3.3287e-05
# Epoch 13/20
# lr: 2.725317930340126e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8811 - loss: 0.3233
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 55s 13s/step - accuracy: 0.8875 - loss: 0.3157 - val_accuracy: 0.8542 - val_loss: 0.3542 - learning_rate: 3.0119e-05
# Epoch 14/20
# lr: 2.465969639416065e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8320 - loss: 0.3934
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 13s/step - accuracy: 0.8500 - loss: 0.3669 - val_accuracy: 0.8698 - val_loss: 0.3257 - learning_rate: 2.7253e-05
# Epoch 15/20
# lr: 2.2313016014842984e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8650 - loss: 0.3627
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 53s 12s/step - accuracy: 0.8562 - loss: 0.3552 - val_accuracy: 0.8594 - val_loss: 0.3332 - learning_rate: 2.4660e-05
# Epoch 16/20
# lr: 2.018965179946554e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8626 - loss: 0.3595
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 12s/step - accuracy: 0.8625 - loss: 0.3759 - val_accuracy: 0.8594 - val_loss: 0.3296 - learning_rate: 2.2313e-05
# Epoch 17/20
# lr: 1.8268352405273466e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9023 - loss: 0.3149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 54s 12s/step - accuracy: 0.8813 - loss: 0.3100 - val_accuracy: 0.8490 - val_loss: 0.3319 - learning_rate: 2.0190e-05
# Epoch 18/20
# lr: 1.6529888822158655e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8515 - loss: 0.3344
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 54s 12s/step - accuracy: 0.8562 - loss: 0.3303 - val_accuracy: 0.8542 - val_loss: 0.3268 - learning_rate: 1.8268e-05

# %% [markdown]
# ### <a id='toc1_11_1_'></a>[Plot loss curves for training and validation sets (extract_feat_model)](#toc0_)

# %%
import matplotlib.pyplot as plt

history_base_model = extract_feat_model

# plot loss curve for training and validation sets
plt.figure(figsize=(5, 5))
plt.plot(history_base_model.history['loss'], label='Training Loss')
plt.plot(history_base_model.history['val_loss'], label='Validation Loss')
plt.title('Custom VGG16 Model Loss Curve')
plt.xlabel('Epochs')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### <a id='toc1_11_2_'></a>[**Task 6: Plot accuracy curves for training and validation sets (extract_feat_model)**](#toc0_)
#
#
# - `figsize=(5, 5)`
# - `plt.plot(history.history['accuracy'], label='Training Accuracy')`
# - `plt.plot(history.history['val_accuracy'], label='Validation Accuracy')`
# - **Title**: `'Accuracy Curve'`
# - **xlabel**: `'Epochs'`
# - **ylabel**: `'Accuracy'`

# %%
import matplotlib.pyplot as plt

history = extract_feat_model

## plot accuracy curves for training and validation sets
plt.figure(figsize=(5, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Custom VGG16 Model Accuracy Curve')
plt.xlabel('Epochs')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## <a id='toc1_12_'></a>[Fine-Tuning model](#toc0_)
#
# Fine-tuning is an optional step in transfer learning, it usually ends up improving the performance of the model.
#
# we will **unfreeze** one layer from the base model and train the model again.

# %%
from tensorflow.keras.applications import vgg16

# VGG16 base model
input_shape = (150, 150, 3)
vgg = vgg16.VGG16(include_top=False,
                        weights='imagenet',
                        input_shape=input_shape)

output = vgg.layers[-1].output
output = tf.keras.layers.Flatten()(output)
basemodel = Model(vgg.input, output)

for layer in basemodel.layers: 
    layer.trainable = False

print('VGG - without Fine-Tuning')
print(f"{'Layer Name'} | {'Trainable'}")
print("-" * 38)
for layer in basemodel.layers:
    print(f"{layer.name}: {layer.trainable}")

print('\n\n')

# Fine-Tuning with custom unfreeze layers
set_trainable = False

for layer in basemodel.layers:
    if layer.name in ['block5_conv3']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
        
print('VGG - with Fine-Tuning')
print(f"{'Layer Name'} | {'Trainable'}")
print("-" * 38)
for layer in basemodel.layers:
    print(f"{layer.name}: {layer.trainable}")
# Out:
# VGG - without Fine-Tuning
# Layer Name | Trainable
# --------------------------------------
# input_layer_2: False
# block1_conv1: False
# block1_conv2: False
# block1_pool: False
# block2_conv1: False
# block2_conv2: False
# block2_pool: False
# block3_conv1: False
# block3_conv2: False
# block3_conv3: False
# block3_pool: False
# block4_conv1: False
# block4_conv2: False
# block4_conv3: False
# block4_pool: False
# block5_conv1: False
# block5_conv2: False
# block5_conv3: False
# block5_pool: False
# flatten_1: False
#
#
#
# VGG - with Fine-Tuning
# Layer Name | Trainable
# --------------------------------------
# input_layer_2: False
# block1_conv1: False
# block1_conv2: False
# block1_pool: False
# block2_conv1: False
# block2_conv2: False
# block2_pool: False
# block3_conv1: False
# block3_conv2: False
# block3_conv3: False
# block3_pool: False
# block4_conv1: False
# block4_conv2: False
# block4_conv3: False
# block4_pool: False
# block5_conv1: False
# block5_conv2: False
# block5_conv3: True
# block5_pool: True
# flatten_1: True

# %% [markdown]
# Similar to what we did before, we will create a new model on top, and add a Dropout layer for regularization.

# %%
# Customizing VGG16 Fully Connected Classifier
model = Sequential()
model.add(basemodel)
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Saving Model 
checkpoint_path='O_R_tlearn_fine_tune_vgg16.keras'

# learning schedule callback
loss_history_ = LossHistory_()
lrate_ = LearningRateScheduler(exp_decay)

# Advance Setting - callback function
keras_callbacks = [
      EarlyStopping(monitor = 'val_loss', 
                    patience = 4, 
                    mode = 'min', 
                    min_delta=0.01),
      ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')
]

callbacks_list_ = [loss_history_, lrate_] + keras_callbacks

#Compile model
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

# Fit the model
fine_tune_model = model.fit(train_generator, 
                    steps_per_epoch=5, 
                    epochs=n_epochs,
                    callbacks = callbacks_list_,   
                    validation_data=val_generator, 
                    validation_steps=val_generator.samples // batch_size, 
                    verbose=1)
# Out:
# Epoch 1/20
# lr: 9.048374180359596e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5194 - loss: 0.8628
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 64s 14s/step - accuracy: 0.5813 - loss: 0.7807 - val_accuracy: 0.7552 - val_loss: 0.5337 - learning_rate: 1.0000e-04
# Epoch 2/20
# lr: 8.187307530779819e-05━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7207 - loss: 0.5162
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 60s 14s/step - accuracy: 0.7312 - loss: 0.5046 - val_accuracy: 0.8125 - val_loss: 0.4796 - learning_rate: 9.0484e-05
# Epoch 3/20
# lr: 7.408182206817179e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8166 - loss: 0.4259
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 13s/step - accuracy: 0.8250 - loss: 0.4332 - val_accuracy: 0.8438 - val_loss: 0.3811 - learning_rate: 8.1873e-05
# Epoch 4/20
# lr: 6.703200460356393e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8509 - loss: 0.3936
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 14s/step - accuracy: 0.8250 - loss: 0.4214 - val_accuracy: 0.8385 - val_loss: 0.3487 - learning_rate: 7.4082e-05
# Epoch 5/20
# lr: 6.065306597126335e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8474 - loss: 0.3633
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 58s 13s/step - accuracy: 0.8438 - loss: 0.3419 - val_accuracy: 0.8385 - val_loss: 0.3128 - learning_rate: 6.7032e-05
# Epoch 6/20
# lr: 5.488116360940264e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8296 - loss: 0.3902
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.8250 - loss: 0.4056 - val_accuracy: 0.8490 - val_loss: 0.3186 - learning_rate: 6.0653e-05
# Epoch 7/20
# lr: 4.9658530379140954e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9081 - loss: 0.2968
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 13s/step - accuracy: 0.9000 - loss: 0.3108 - val_accuracy: 0.8646 - val_loss: 0.3004 - learning_rate: 5.4881e-05
# Epoch 8/20
# lr: 4.493289641172216e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8919 - loss: 0.3023
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.8813 - loss: 0.3073 - val_accuracy: 0.8594 - val_loss: 0.2838 - learning_rate: 4.9659e-05
# Epoch 9/20
# lr: 4.0656965974059915e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8798 - loss: 0.3042
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.8938 - loss: 0.2976 - val_accuracy: 0.8854 - val_loss: 0.2660 - learning_rate: 4.4933e-05
# Epoch 10/20
# lr: 3.678794411714424e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8962 - loss: 0.3112
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 55s 13s/step - accuracy: 0.8875 - loss: 0.3260 - val_accuracy: 0.8750 - val_loss: 0.2778 - learning_rate: 4.0657e-05
# Epoch 11/20
# lr: 3.3287108369807955e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8446 - loss: 0.3448
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.8375 - loss: 0.3277 - val_accuracy: 0.8646 - val_loss: 0.2748 - learning_rate: 3.6788e-05
# Epoch 12/20
# lr: 3.0119421191220204e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8278 - loss: 0.3923
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.8500 - loss: 0.3540 - val_accuracy: 0.8906 - val_loss: 0.2540 - learning_rate: 3.3287e-05
# Epoch 13/20
# lr: 2.725317930340126e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8891 - loss: 0.2851
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 13s/step - accuracy: 0.8750 - loss: 0.3133 - val_accuracy: 0.8906 - val_loss: 0.2473 - learning_rate: 3.0119e-05
# Epoch 14/20
# lr: 2.465969639416065e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8739 - loss: 0.2843
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 55s 12s/step - accuracy: 0.8875 - loss: 0.2906 - val_accuracy: 0.9062 - val_loss: 0.2525 - learning_rate: 2.7253e-05
# Epoch 15/20
# lr: 2.2313016014842984e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8872 - loss: 0.3137
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.8813 - loss: 0.2903 - val_accuracy: 0.9010 - val_loss: 0.2401 - learning_rate: 2.4660e-05
# Epoch 16/20
# lr: 2.018965179946554e-05━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8830 - loss: 0.2615
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 97s 13s/step - accuracy: 0.8500 - loss: 0.3071 - val_accuracy: 0.8958 - val_loss: 0.2366 - learning_rate: 2.2313e-05
# Epoch 17/20
# lr: 1.8268352405273466e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9251 - loss: 0.2620
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 13s/step - accuracy: 0.9250 - loss: 0.2328 - val_accuracy: 0.9062 - val_loss: 0.2343 - learning_rate: 2.0190e-05
# Epoch 18/20
# lr: 1.6529888822158655e-05━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8891 - loss: 0.2447
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 13s/step - accuracy: 0.8750 - loss: 0.2767 - val_accuracy: 0.9010 - val_loss: 0.2455 - learning_rate: 1.8268e-05
# Epoch 19/20
# lr: 1.4956861922263504e-05━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8999 - loss: 0.2548
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 57s 13s/step - accuracy: 0.9187 - loss: 0.2445 - val_accuracy: 0.8958 - val_loss: 0.2506 - learning_rate: 1.6530e-05

# %% [markdown]
# ### <a id='toc1_12_1_'></a>[**Task 7: Plot loss curves for training and validation sets (fine tune model)**](#toc0_)
#
# - `hirtory_finetune = fine_tune_model`
# - `figsize=(5, 5)`
# - `plt.plot(hirtory_finetune.history['loss'], label='Training Loss')`
# - `plt.plot(hirtory_finetune.history['val_loss'], label='Validation Loss')`
# - **Title**: `'Loss Curve'`
# - **xlabel**: `'Epochs'`
# - **ylabel**: `'Loss'`

# %%
hirtory_finetune = fine_tune_model

# Plot loss curves for training and validation sets (fine tune model)
plt.figure(figsize=(5, 5))
plt.plot(hirtory_finetune.history['loss'], label='Training Loss')
plt.plot(hirtory_finetune.history['val_loss'], label='Validation Loss')
plt.title('Fine-Tuning Model Loss Curve')
plt.xlabel('Epochs')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### <a id='toc1_12_2_'></a>[**Task 8: Plot accuracy curves for training and validation sets  (fine tune model)**](#toc0_)
#
# - `history = fine_tune_model`
# - `figsize=(5, 5)`
# - `plt.plot(history.history['accuracy'], label='Training Accuracy')`
# - `plt.plot(history.history['val_accuracy'], label='Validation Accuracy')`
# - **Title**: `'Accuracy Curve'`
# - **xlabel**: `'Epochs'`
# - **ylabel**: `'Accuracy'`

# %%
history_finetune = fine_tune_model

# Plot accuracy curves for training and validation sets (fine tune model) 
plt.figure(figsize=(5, 5))
plt.plot(history_finetune.history['accuracy'], label='Training Accuracy')
plt.plot(history_finetune.history['val_accuracy'], label='Validation Accuracy')
plt.title('Fine-Tuning Model Accuracy Curve') 
plt.xlabel('Epochs') 
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Accuracy') 
plt.legend()
plt.show()

# %% [markdown]
# <br>
#
# ### <a id='toc1_12_3_'></a>[Summary Model Performance](#toc0_)

# %% [markdown]
# #### [Compare Models Accuracy](#toc0_)

# %% [markdown]
# ##### [Training Accuracy](#toc0_)

# %%
# Compare the accuracy curves of Custom VGG16 model with Fine-tuning Custom VGG16 model for training and validation sets
plt.figure(figsize=(5, 5))

# model accuracy without Fine-Tuning
plt.plot(history_base_model.history['accuracy'], label='VGG16')
# Fine-Tuning model Accuracy
plt.plot(history_finetune.history['accuracy'], label='VGG16-FineTuning')

plt.title('FineTuning vs Base Model Accuracy Curve (Training set)')
plt.xlabel('Epochs')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ##### [Validation Accuracy](#toc0_)

# %%
# Compare the accuracy curves of Custom VGG16 model with Fine-tuning Custom VGG16 model for training and validation sets
plt.figure(figsize=(5, 5))

# model accuracy without Fine-Tuning
plt.plot(history_base_model.history['val_accuracy'], label='VGG16')
# Fine-Tuning model Accuracy
plt.plot(history_finetune.history['val_accuracy'], label='VGG16-FineTuning')

plt.title('FineTuning vs Base Model Accuracy Curve (Validation set)')
plt.xlabel('Epochs')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### [Compare Models Loss](#toc0_)

# %% [markdown]
# ##### [Training Loss](#toc0_)

# %%
# Compare the loss curves of Custom VGG16 model with Fine-tuning Custom VGG16 model for training sets
plt.figure(figsize=(5, 5))

# model loss without Fine-Tuning
plt.plot(history_base_model.history['loss'], label='VGG16')
# Fine-Tuning model loss
plt.plot(history_finetune.history['loss'], label='VGG16-FineTuning')

plt.title('FineTuning vs Base Model Loss Curve (Training set)')
plt.xlabel('Epochs')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ##### [Validation Loss](#toc0_)

# %%
# Compare the loss curves of Custom VGG16 model with Fine-tuning Custom VGG16 model for training and validation sets
plt.figure(figsize=(5, 5))

# model loss without Fine-Tuning
plt.plot(history_base_model.history['val_loss'], label='VGG16')
# Fine-Tuning model loss
plt.plot(history_finetune.history['val_loss'], label='VGG16-FineTuning')

plt.title('FineTuning vs Base Model Loss Curve (Validation set)')
plt.xlabel('Epochs')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## <a id='toc1_13_'></a>[Evaluate both models on Test data (Unseen data)](#toc0_)
#
# - Load saved models
# - Load test images
# - Make predictions for both models
# - Convert predictions to class labels
# - Observe classification report for both models

# %%
from pathlib import Path

# Load saved models
extract_feat_model = tf.keras.models.load_model('O_R_tlearn_vgg16.keras')
fine_tune_model = tf.keras.models.load_model('O_R_tlearn_fine_tune_vgg16.keras')

IMG_DIM = (150, 150)

# Load test images
test_files_O = glob.glob('./o-vs-r-split/test/O/*')
test_files_R = glob.glob('./o-vs-r-split/test/R/*')
test_files = test_files_O[:50] + test_files_R[:50]

test_imgs = [tf.keras.preprocessing.image.img_to_array(tf.keras.preprocessing.image.load_img(img, target_size=IMG_DIM)) for img in test_files]
test_imgs = np.array(test_imgs)
test_labels = [Path(fn).parent.name for fn in test_files]

# Standardize
test_imgs_scaled = test_imgs.astype('float32')
test_imgs_scaled /= 255

class2num_lt = lambda l: [0 if x == 'O' else 1 for x in l]
num2class_lt = lambda l: ['O' if x < 0.5 else 'R' for x in l]

test_labels_enc = class2num_lt(test_labels)

# Make predictions for both models
predictions_extract_feat_model = extract_feat_model.predict(test_imgs_scaled, verbose=0)
predictions_fine_tune_model = fine_tune_model.predict(test_imgs_scaled, verbose=0)

# Convert predictions to class labels
predictions_extract_feat_model = num2class_lt(predictions_extract_feat_model)
predictions_fine_tune_model = num2class_lt(predictions_fine_tune_model)

# Print classification report for both models
print('Extract Features Model')
print(metrics.classification_report(test_labels, predictions_extract_feat_model))
print('\n')
print('Fine-Tuned Model')
print(metrics.classification_report(test_labels, predictions_fine_tune_model))
# Out:
# Extract Features Model
#               precision    recall  f1-score   support
#
#            O       0.76      0.76      0.76        50
#            R       0.76      0.76      0.76        50
#
#     accuracy                           0.76       100
#    macro avg       0.76      0.76      0.76       100
# weighted avg       0.76      0.76      0.76       100
#
#
#
# Fine-Tuned Model
#               precision    recall  f1-score   support
#
#            O       0.77      0.88      0.82        50
#            R       0.86      0.74      0.80        50
#
#     accuracy                           0.81       100
#    macro avg       0.82      0.81      0.81       100
# weighted avg       0.82      0.81      0.81       100

# %%
# Plot one of the images with actual label and predicted label as title
def plot_image_with_title(image, model_name, actual_label, predicted_label):
    plt.imshow(image)
    plt.title(f"Model: {model_name}, Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis('off')
    plt.show()

# Specify index of image to plot, for example index 0
index_to_plot = 0
plot_image_with_title(
    image=test_imgs[index_to_plot].astype('uint8'),
    model_name='Extract Features Model',
    actual_label=test_labels[index_to_plot], 
    predicted_label=predictions_extract_feat_model[index_to_plot],
    )

# %% [markdown]
# ### <a id='toc1_13_1_'></a>[**Task 9: Plot a test image using Extract Features Model (index_to_plot = 6)**](#toc0_)
#
# - Use `plot_image_with_title` function.
# - `index_to_plot = 6`
# - `model_name='Extract Features Model'`
# - `predicted_label=predictions_extract_feat_model[index_to_plot]`

# %%
index_to_plot = 6

plot_image_with_title(
    image=test_imgs[index_to_plot].astype('uint8'),
    model_name='Extract Features Model',
    actual_label=test_labels[index_to_plot], 
    predicted_label=predictions_extract_feat_model[index_to_plot],
    )

# %% [markdown]
# ### <a id='toc1_13_2_'></a>[**Task 10: Plot a test image using Fine-Tuned Model (index_to_plot = 6)**](#toc0_)
#
# - Use `plot_image_with_title` function.
# - `index_to_plot = 6`
# - `model_name='Fine-Tuned Model'`
# - `predicted_label=predictions_fine_tune_model[index_to_plot]`

# %%
index_to_plot = 6

plot_image_with_title(
    image=test_imgs[index_to_plot].astype('uint8'),
    model_name='Fine-Tuned Model',
    actual_label=test_labels[index_to_plot], 
    predicted_label=predictions_fine_tune_model[index_to_plot],
    )

# %% [markdown]
# ### [**Conclusion**](#toc0_)
#
# In this project, we developed an automated waste classification model to accurately differentiate between organic and recyclable waste. By leveraging transfer learning with the VGG16 architecture , we attached a custom fully connected layer to adapt the pre-trained network to our specific classification task.
#
# The experimental results demonstrate that the fine-tuned VGG16 model achieved superior performance compared to the base feature extraction model (without fine-tuning). Specifically, the fine-tuning process resulted in better accuracy and lower loss metrics. This confirms that unfreezing and retraining the later layers of the network allowed the model to effectively learn the specific visual features of the waste dataset, ultimately yielding a more robust and reliable model for automated waste sorting applications.
